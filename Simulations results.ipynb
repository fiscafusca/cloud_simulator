# %% [markdown]
# # Results of the simulations

# %%
import pandas as pd

# %%
withPolicy1 = pd.read_csv("csv/withPolicy1.csv")
noPolicy1 = pd.read_csv("csv/noPolicy1.csv")

withPolicy2 = pd.read_csv("csv/withPolicy2.csv")
noPolicy2 = pd.read_csv("csv/noPolicy2.csv")

withPolicy3 = pd.read_csv("csv/withPolicy3.csv")
noPolicy3 = pd.read_csv("csv/noPolicy3.csv")

withPolicy4 = pd.read_csv("csv/withPolicy4.csv")
noPolicy4 = pd.read_csv("csv/noPolicy4.csv")

# %% [markdown]
# ## withPolicy1:
# - \# of single-core VMs ≥ \# of dual-core VMs & \# of single-core cloudlets ≥ \# of dual-core cloudlets <br>
# - scheduling policy **enabled**

# %%
withPolicy1
# Out:
#    Cloudlet ID     Type   STATUS  Data center ID  VM ID  Time  Start Time  \
# 0          M_2   MAPPER  SUCCESS               2    102  40.0        11.2
# 1          M_0   MAPPER  SUCCESS               2    100  40.0        11.2
# 2          M_1   MAPPER  SUCCESS               2    101  40.0        11.2
# 3          M_3   MAPPER  SUCCESS               3    103  40.0        12.2
# 4          M_4   MAPPER  SUCCESS               3    104  40.0        12.2
# 5          G_0  GENERAL  SUCCESS               2      0  81.4        11.2
# 6          G_2  GENERAL  SUCCESS               2      2  81.4        11.2
# 7          G_4  GENERAL  SUCCESS               2      4  81.4        11.2
# 8          M_7   MAPPER  SUCCESS               2    102  40.0        51.2
# 9          G_1  GENERAL  SUCCESS               2      1  81.4        11.2
# 10         G_3  GENERAL  SUCCESS               2      3  81.4        11.2
# 11         M_5   MAPPER  SUCCESS               2    100  40.0        51.2
# ...

# %% [markdown]
# **Overall execution time =** 105.0 ms<br>
# **Overall cost =** 27.21

# %% [markdown]
# ## noPolicy1
# - \# of single-core VMs ≥ \# of dual-core VMs & \# of single-core cloudlets ≥ \# of dual-core cloudlets <br>
# - scheduling policy **disabled**

# %%
noPolicy1
# Out:
#    Cloudlet ID     Type   STATUS  Data center ID  VM ID  Time  Start Time  \
# 0          M_0   MAPPER  SUCCESS               2      0  41.4        11.2
# 1          M_2   MAPPER  SUCCESS               2      2  41.4        11.2
# 2          M_4   MAPPER  SUCCESS               2      4  41.4        11.2
# 3          M_7   MAPPER  SUCCESS               2    102  40.0        11.2
# 4          M_1   MAPPER  SUCCESS               2      1  41.4        11.2
# 5          M_3   MAPPER  SUCCESS               2      3  41.4        11.2
# 6          M_5   MAPPER  SUCCESS               2    100  40.0        11.2
# 7          M_6   MAPPER  SUCCESS               2    101  40.0        11.2
# 8          M_8   MAPPER  SUCCESS               3    103  40.0        12.2
# 9          M_9   MAPPER  SUCCESS               3    104  40.0        12.2
# 10         R_2  REDUCER  SUCCESS               2    102  20.0        53.2
# 11         R_0  REDUCER  SUCCESS               2    100  20.0        53.2
# ...

# %% [markdown]
# **Overall execution time =** 121.4 ms<br>
# **Overall cost =** 27.42

# %% [markdown]
# ## withPolicy 2
# - \# of single-core VMs ≥ \# of dual-core VMs & \# of single-core cloudlets < \# of dual-core cloudlets <br>
# - scheduling policy **enabled**

# %%
withPolicy2
# Out:
#    Cloudlet ID     Type   STATUS  Data center ID  VM ID  Time  Start Time  \
# 0          M_0   MAPPER  SUCCESS               2    100  40.0        11.2
# 1          M_2   MAPPER  SUCCESS               2    102  40.0        11.2
# 2          M_1   MAPPER  SUCCESS               2    101  40.0        11.2
# 3          M_3   MAPPER  SUCCESS               2    103  40.0        11.2
# 4          M_8   MAPPER  SUCCESS               3    104  40.0        12.2
# 5          M_9   MAPPER  SUCCESS               3    105  40.0        12.2
# 6          G_0  GENERAL  SUCCESS               2      0  81.4        11.2
# 7          G_2  GENERAL  SUCCESS               2      2  81.4        11.2
# 8          M_4   MAPPER  SUCCESS               2    100  40.0        51.2
# 9          M_6   MAPPER  SUCCESS               2    102  40.0        51.2
# 10         G_1  GENERAL  SUCCESS               2      1  81.4        11.2
# 11         G_3  GENERAL  SUCCESS               2      3  81.4        11.2
# ...

# %% [markdown]
# **Overall execution time =** 161.4 ms<br>
# **Overall cost =** 34.54

# %% [markdown]
# ## noPolicy2
# - \# of single-core VMs ≥ \# of dual-core VMs & \# of single-core cloudlets < \# of dual-core cloudlets <br>
# - scheduling policy **disabled**

# %%
noPolicy2
# Out:
#    Cloudlet ID     Type   STATUS  Data center ID  VM ID  Time  Start Time  \
# 0          M_0   MAPPER  SUCCESS               2      0  41.4        11.2
# 1          M_2   MAPPER  SUCCESS               2      2  41.4        11.2
# 2          M_4   MAPPER  SUCCESS               2    100  40.0        11.2
# 3          M_6   MAPPER  SUCCESS               2    102  40.0        11.2
# 4          M_1   MAPPER  SUCCESS               2      1  41.4        11.2
# 5          M_3   MAPPER  SUCCESS               2      3  41.4        11.2
# 6          M_5   MAPPER  SUCCESS               2    101  40.0        11.2
# 7          M_7   MAPPER  SUCCESS               2    103  40.0        11.2
# 8          M_8   MAPPER  SUCCESS               3    104  40.0        12.2
# 9          M_9   MAPPER  SUCCESS               3    105  40.0        12.2
# 10         R_1  REDUCER  SUCCESS               2    102  20.0        53.2
# 11         R_0  REDUCER  SUCCESS               2    101  20.0        53.2
# ...

# %% [markdown]
# **Overall execution time =** 201.0 ms<br>
# **Overall cost =** 34.70

# %% [markdown]
# ## withPolicy3
# - \# of single-core VMs < \# of dual-core VMs & \# of single-core cloudlets < \# of dual-core cloudlets <br>
# - scheduling policy **enabled**

# %%
withPolicy3
# Out:
#    Cloudlet ID     Type   STATUS  Data center ID  VM ID  Time  Start Time  \
# 0         2M_0   MAPPER  SUCCESS               2    100  40.0        11.2
# 1         2M_1   MAPPER  SUCCESS               2    101  40.0        11.2
# 2         2M_2   MAPPER  SUCCESS               3    102  40.0        12.2
# 3         2M_3   MAPPER  SUCCESS               3    103  40.0        12.2
# 4         2G_0  GENERAL  SUCCESS               2      0  81.4        11.2
# 5         2G_2  GENERAL  SUCCESS               2      2  81.4        11.2
# 6         2G_4  GENERAL  SUCCESS               2      4  81.4        11.2
# 7         2M_4   MAPPER  SUCCESS               2    100  40.0        51.2
# 8         2G_1  GENERAL  SUCCESS               2      1  81.4        11.2
# 9         2G_3  GENERAL  SUCCESS               2      3  81.4        11.2
# 10        2G_5  GENERAL  SUCCESS               2      5  81.4        11.2
# 11        2M_5   MAPPER  SUCCESS               2    101  40.0        51.2
# ...

# %% [markdown]
# **Overall execution time =** 161.0 ms<br>
# **Overall cost =** 41.86

# %% [markdown]
# ## noPolicy3
# - \# of single-core VMs < \# of dual-core VMs & \# of single-core cloudlets < \# of dual-core cloudlets <br>
# - scheduling policy **disabled**

# %%
noPolicy3
# Out:
#    Cloudlet ID     Type   STATUS  Data center ID  VM ID  Time  Start Time  \
# 0          M_0   MAPPER  SUCCESS               2      0  41.4        11.2
# 1          M_2   MAPPER  SUCCESS               2      2  41.4        11.2
# 2          M_4   MAPPER  SUCCESS               2      4  41.4        11.2
# 3          M_6   MAPPER  SUCCESS               2    100  40.0        11.2
# 4          M_1   MAPPER  SUCCESS               2      1  41.4        11.2
# 5          M_3   MAPPER  SUCCESS               2      3  41.4        11.2
# 6          M_5   MAPPER  SUCCESS               2      5  41.4        11.2
# 7          M_7   MAPPER  SUCCESS               2    101  40.0        11.2
# 8          M_8   MAPPER  SUCCESS               3    102  40.0        12.2
# 9          M_9   MAPPER  SUCCESS               3    103  40.0        12.2
# 10         R_1  REDUCER  SUCCESS               2    100  20.0        53.2
# 11         R_2  REDUCER  SUCCESS               2    101  20.0        53.2
# ...

# %% [markdown]
# **Overall execution time =** 201.4 ms<br>
# **Overall cost =** 42.16

# %% [markdown]
# ## withPolicy4
# - \# of single-core VMs < \# of dual-core VMs & \# of single-core cloudlets ≥ \# of dual-core cloudlets <br>
# - scheduling policy **enabled**

# %%
withPolicy4
# Out:
#    Cloudlet ID     Type   STATUS  Data center ID  VM ID  Time  Start Time  \
# 0          M_0   MAPPER  SUCCESS               2    100  40.0        11.2
# 1          M_1   MAPPER  SUCCESS               2    101  40.0        11.2
# 2          M_2   MAPPER  SUCCESS               3    102  40.0        12.2
# 3          M_3   MAPPER  SUCCESS               3    103  40.0        12.2
# 4          G_0  GENERAL  SUCCESS               2      0  81.4        11.2
# 5          G_2  GENERAL  SUCCESS               2      2  81.4        11.2
# 6          G_4  GENERAL  SUCCESS               2      4  81.4        11.2
# 7          M_4   MAPPER  SUCCESS               2    100  40.0        51.2
# 8          G_1  GENERAL  SUCCESS               2      1  81.4        11.2
# 9          G_3  GENERAL  SUCCESS               2      3  81.4        11.2
# 10         M_5   MAPPER  SUCCESS               2    101  40.0        51.2
# 11         M_8   MAPPER  SUCCESS               3    102  40.0        52.2
# ...

# %% [markdown]
# **Overall execution time =** 143.0 ms<br>
# **Overall cost =** 27.21

# %% [markdown]
# ## noPolicy4
# - \# of single-core VMs < \# of dual-core VMs & \# of single-core cloudlets ≥ \# of dual-core cloudlets <br>
# - scheduling policy **disabled**

# %%
noPolicy4
# Out:
#    Cloudlet ID     Type   STATUS  Data center ID  VM ID  Time  Start Time  \
# 0          M_0   MAPPER  SUCCESS               2      0  41.4        11.2
# 1          M_2   MAPPER  SUCCESS               2      2  41.4        11.2
# 2          M_4   MAPPER  SUCCESS               2      4  41.4        11.2
# 3          M_6   MAPPER  SUCCESS               2    100  40.0        11.2
# 4          M_1   MAPPER  SUCCESS               2      1  41.4        11.2
# 5          M_3   MAPPER  SUCCESS               2      3  41.4        11.2
# 6          M_5   MAPPER  SUCCESS               2      5  41.4        11.2
# 7          M_7   MAPPER  SUCCESS               2    101  40.0        11.2
# 8          M_8   MAPPER  SUCCESS               3    102  40.0        12.2
# 9          M_9   MAPPER  SUCCESS               3    103  40.0        12.2
# 10         R_1  REDUCER  SUCCESS               2    100  20.0        53.2
# 11         R_0  REDUCER  SUCCESS               2      5  21.4        53.2
# ...

# %% [markdown]
# **Overall execution time =** 121.4 ms<br>
# **Overall cost =** 27.50
